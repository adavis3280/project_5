# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
from pandas.io import gbq
from google.cloud import bigquery
from google.oauth2 import service_account

# %% [markdown]
# # Google Database BigQuery Code (Start here) >>>

# %%
# !pip install --upgrade google-cloud-bigquery
# !pip install pandas-gbq
# !pip install google-cloud-bigquery

# %%
credentials = service_account.Credentials.from_service_account_file("p5_cred.json")
project_id = 'banded-water-276418'

# %%
client = bigquery.Client(credentials= credentials,project='banded-water-276418')

# %% [markdown]
# # Hurricanes >>>

# %%
# Harvey >>>
# Q1
harvey_1 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q1` AS b
WHERE  (b.area_fips = '48201' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48039' OR 
        b.area_fips = '48321' OR
        b.area_fips = '48007' OR
        b.area_fips = '48409' OR
        b.area_fips = '48355' OR
        b.area_fips = '48273')
"""
# Q2 
harvey_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q2` AS b
WHERE  (b.area_fips = '48201' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48039' OR 
        b.area_fips = '48321' OR
        b.area_fips = '48007' OR
        b.area_fips = '48409' OR
        b.area_fips = '48355' OR
        b.area_fips = '48273')
"""
# Q3
harvey_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q3` AS b
WHERE  (b.area_fips = '48201' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48039' OR 
        b.area_fips = '48321' OR
        b.area_fips = '48007' OR
        b.area_fips = '48409' OR
        b.area_fips = '48355' OR
        b.area_fips = '48273')
"""
# Q4
harvey_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q4` AS b
WHERE  (b.area_fips = '48201' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48039' OR 
        b.area_fips = '48321' OR
        b.area_fips = '48007' OR
        b.area_fips = '48409' OR
        b.area_fips = '48355' OR
        b.area_fips = '48273')
"""

harvey_q1 = gbq.read_gbq(harvey_1, project_id='banded-water-276418')
harvey_q2 = gbq.read_gbq(harvey_2, project_id='banded-water-276418')
harvey_q3 = gbq.read_gbq(harvey_3, project_id='banded-water-276418')
harvey_q4 = gbq.read_gbq(harvey_4, project_id='banded-water-276418')

harvey_df = pd.concat([harvey_q1, harvey_q2, harvey_q3, harvey_q4])

harvey_df.to_csv('datasets/harvey.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 38.68rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 46.56rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 40.67rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 27.01rows/s]

# %%
# Katrina >>>
# Q1
katrina_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q1` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""
# Q2 
katrina_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q2` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""
# Q3
katrina_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q3` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""
# Q4
katrina_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q4` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""

katrina_q1 = gbq.read_gbq(katrina_1, project_id='banded-water-276418')  # Edit Hurricane Here.
katrina_q2 = gbq.read_gbq(katrina_2, project_id='banded-water-276418')  # Edit Hurricane Here.
katrina_q3 = gbq.read_gbq(katrina_3, project_id='banded-water-276418')  # Edit Hurricane Here.
katrina_q4 = gbq.read_gbq(katrina_4, project_id='banded-water-276418')  # Edit Hurricane Here.

katrina_df = pd.concat([katrina_q1, katrina_q2, katrina_q3, katrina_q4])

katrina_df.to_csv('datasets/katrina.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 27.70rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 24.02rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 21.18rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 22.36rows/s]

# %%
# Maria >>>
# Q1
maria_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q1` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR 
        b.area_fips = '72113')
"""
# Q2 
maria_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q2` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR 
        b.area_fips = '72113')
"""
# Q3
maria_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q3` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR 
        b.area_fips = '72113')
"""
# Q4
maria_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q4` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR 
        b.area_fips = '72113')
"""

maria_q1 = gbq.read_gbq(maria_1, project_id='banded-water-276418')  # Edit Hurricane Here.
maria_q2 = gbq.read_gbq(maria_2, project_id='banded-water-276418')  # Edit Hurricane Here.
maria_q3 = gbq.read_gbq(maria_3, project_id='banded-water-276418')  # Edit Hurricane Here.
maria_q4 = gbq.read_gbq(maria_4, project_id='banded-water-276418')  # Edit Hurricane Here.

maria_df = pd.concat([maria_q1, maria_q2, maria_q3, maria_q4])

maria_df.to_csv('datasets/maria.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 26.24rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 28.14rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 29.12rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 23.56rows/s]

# %%
# Andrew >>>
# Q1
andrew_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.1992_q1` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR 
        b.area_fips = '12087')
"""
# Q2 
andrew_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.1992_q2` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR 
        b.area_fips = '12087')
"""
# Q3
andrew_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.1992_q3` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR 
        b.area_fips = '12087')
"""
# Q4
andrew_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.1992_q4` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR 
        b.area_fips = '12087')
"""

andrew_q1 = gbq.read_gbq(andrew_1, project_id='banded-water-276418')  # Edit Hurricane Here.
andrew_q2 = gbq.read_gbq(andrew_2, project_id='banded-water-276418')  # Edit Hurricane Here.
andrew_q3 = gbq.read_gbq(andrew_3, project_id='banded-water-276418')  # Edit Hurricane Here.
andrew_q4 = gbq.read_gbq(andrew_4, project_id='banded-water-276418')  # Edit Hurricane Here.

andrew_df = pd.concat([andrew_q1, andrew_q2, andrew_q3, andrew_q4])

andrew_df.to_csv('datasets/andrew.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 14.03rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 17.34rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 14.07rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 13.60rows/s]

# %%
# Sandy >>>
# Q1
sandy_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2012_q1` AS b
WHERE  (b.area_fips = '36103' OR 
        b.area_fips = '36059' OR 
        b.area_fips = '36081' OR 
        b.area_fips = '36005' OR
        b.area_fips = '36647' OR
        b.area_fips = '36119' OR
        b.area_fips = '36061')
"""
# Q2 
sandy_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2012_q2` AS b
WHERE  (b.area_fips = '36103' OR 
        b.area_fips = '36059' OR 
        b.area_fips = '36081' OR 
        b.area_fips = '36005' OR
        b.area_fips = '36647' OR
        b.area_fips = '36119' OR
        b.area_fips = '36061')
"""
# Q3
sandy_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2012_q3` AS b
WHERE  (b.area_fips = '36103' OR 
        b.area_fips = '36059' OR 
        b.area_fips = '36081' OR 
        b.area_fips = '36005' OR
        b.area_fips = '36647' OR
        b.area_fips = '36119' OR
        b.area_fips = '36061')
"""
# Q4
sandy_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2012_q4` AS b
WHERE  (b.area_fips = '36103' OR 
        b.area_fips = '36059' OR 
        b.area_fips = '36081' OR 
        b.area_fips = '36005' OR
        b.area_fips = '36647' OR
        b.area_fips = '36119' OR
        b.area_fips = '36061')
"""

sandy_q1 = gbq.read_gbq(sandy_1, project_id='banded-water-276418')  # Edit Hurricane Here.
sandy_q2 = gbq.read_gbq(sandy_2, project_id='banded-water-276418')  # Edit Hurricane Here.
sandy_q3 = gbq.read_gbq(sandy_3, project_id='banded-water-276418')  # Edit Hurricane Here.
sandy_q4 = gbq.read_gbq(sandy_4, project_id='banded-water-276418')  # Edit Hurricane Here.

sandy_df = pd.concat([sandy_q1, sandy_q2, sandy_q3, sandy_q4])

sandy_df.to_csv('datasets/sandy.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 32.58rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 31.32rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 24.68rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 29.24rows/s]

# %%
# Irma >>>
# Q1
irma_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q1` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR
        b.area_fips = '72113' OR
        b.area_fips = '12025' OR
        b.area_fips = '12011' OR
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR
        b.area_fips = '12071' OR
        b.area_fips = '12051' OR
        b.area_fips = '12115')
"""
# Q2 
irma_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q2` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR
        b.area_fips = '72113' OR
        b.area_fips = '12025' OR
        b.area_fips = '12011' OR
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR
        b.area_fips = '12071' OR
        b.area_fips = '12051' OR
        b.area_fips = '12115')
"""
# Q3
irma_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q3` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR
        b.area_fips = '72113' OR
        b.area_fips = '12025' OR
        b.area_fips = '12011' OR
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR
        b.area_fips = '12071' OR
        b.area_fips = '12051' OR
        b.area_fips = '12115')
"""
# Q4
irma_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q4` AS b
WHERE  (b.area_fips = '72127' OR 
        b.area_fips = '72021' OR 
        b.area_fips = '72013' OR 
        b.area_fips = '72025' OR
        b.area_fips = '72113' OR
        b.area_fips = '12025' OR
        b.area_fips = '12011' OR
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR
        b.area_fips = '12071' OR
        b.area_fips = '12051' OR
        b.area_fips = '12115')
"""

irma_q1 = gbq.read_gbq(irma_1, project_id='banded-water-276418')  # Edit Hurricane Here.
irma_q2 = gbq.read_gbq(irma_2, project_id='banded-water-276418')  # Edit Hurricane Here.
irma_q3 = gbq.read_gbq(irma_3, project_id='banded-water-276418')  # Edit Hurricane Here.
irma_q4 = gbq.read_gbq(irma_4, project_id='banded-water-276418')  # Edit Hurricane Here.

irma_df = pd.concat([irma_q1, irma_q2, irma_q3, irma_q4])

irma_df.to_csv('datasets/irma.csv', index=False)
# Out:
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 51.84rows/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 60.84rows/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 27.58rows/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 60.41rows/s]

# %%
# Ike >>>
# Q1
ike_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2008_q1` AS b
WHERE  (b.area_fips = '48071' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48201')
"""
# Q2 
ike_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2008_q1` AS b
WHERE  (b.area_fips = '48071' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48201')
"""
# Q3
ike_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2008_q1` AS b
WHERE  (b.area_fips = '48071' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48201')
"""
# Q4
ike_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2008_q1` AS b
WHERE  (b.area_fips = '48071' OR 
        b.area_fips = '48167' OR 
        b.area_fips = '48245' OR 
        b.area_fips = '48201')
"""

ike_q1 = gbq.read_gbq(ike_1, project_id='banded-water-276418')  # Edit Hurricane Here.
ike_q2 = gbq.read_gbq(ike_2, project_id='banded-water-276418')  # Edit Hurricane Here.
ike_q3 = gbq.read_gbq(ike_3, project_id='banded-water-276418')  # Edit Hurricane Here.
ike_q4 = gbq.read_gbq(ike_4, project_id='banded-water-276418')  # Edit Hurricane Here.

ike_df = pd.concat([ike_q1, ike_q2, ike_q3, ike_q4])

ike_df.to_csv('datasets/ike.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 18.06rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 20.44rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 14.21rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 20.82rows/s]

# %%
# Wilma >>>
# Q1
wilma_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q1` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR 
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR 
        b.area_fips = '12071' OR
        b.area_fips = '12051')
"""
# Q2 
wilma_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q1` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR 
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR 
        b.area_fips = '12071' OR
        b.area_fips = '12051')
"""
# Q3
wilma_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q1` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR 
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR 
        b.area_fips = '12071' OR
        b.area_fips = '12051')
"""
# Q4
wilma_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q1` AS b
WHERE  (b.area_fips = '12025' OR 
        b.area_fips = '12011' OR 
        b.area_fips = '12099' OR
        b.area_fips = '12087' OR 
        b.area_fips = '12043' OR
        b.area_fips = '12021' OR 
        b.area_fips = '12071' OR
        b.area_fips = '12051')
"""

wilma_q1 = gbq.read_gbq(wilma_1, project_id='banded-water-276418')  # Edit Hurricane Here.
wilma_q2 = gbq.read_gbq(wilma_2, project_id='banded-water-276418')  # Edit Hurricane Here.
wilma_q3 = gbq.read_gbq(wilma_3, project_id='banded-water-276418')  # Edit Hurricane Here.
wilma_q4 = gbq.read_gbq(wilma_4, project_id='banded-water-276418')  # Edit Hurricane Here.

wilma_df = pd.concat([wilma_q1, wilma_q2, wilma_q3, wilma_q4])

wilma_df.to_csv('datasets/wilma.csv', index=False)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 35.35rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 30.49rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 31.91rows/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 30.04rows/s]

# %%
# Ivan >>>
# Q1
ivan_1 = """ 
SELECT *
FROM `bigquery-public-data.bls_qcew.2004_q1` AS b
WHERE  (b.area_fips = '22051' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22095' OR 
        b.area_fips = '22093' OR
        b.area_fips = '01003' OR 
        b.area_fips = '01053' OR
        b.area_fips = '01097' OR
        b.area_fips = '12045' OR
        b.area_fips = '12095' OR
        b.area_fips = '12113')
"""
# Q2 
ivan_2 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2004_q1` AS b
WHERE  (b.area_fips = '22051' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22095' OR 
        b.area_fips = '22093' OR
        b.area_fips = '01003' OR 
        b.area_fips = '01053' OR
        b.area_fips = '01097' OR
        b.area_fips = '12045' OR
        b.area_fips = '12095' OR
        b.area_fips = '12113')
"""
# Q3
ivan_3 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2004_q1` AS b
WHERE  (b.area_fips = '22051' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22095' OR 
        b.area_fips = '22093' OR
        b.area_fips = '01003' OR 
        b.area_fips = '01053' OR
        b.area_fips = '01097' OR
        b.area_fips = '12045' OR
        b.area_fips = '12095' OR
        b.area_fips = '12113')
"""
# Q4
ivan_4 = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2004_q1` AS b
WHERE  (b.area_fips = '22051' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22095' OR 
        b.area_fips = '22093' OR
        b.area_fips = '01003' OR 
        b.area_fips = '01053' OR
        b.area_fips = '01097' OR
        b.area_fips = '12045' OR
        b.area_fips = '12095' OR
        b.area_fips = '12113')
"""

ivan_q1 = gbq.read_gbq(ivan_1, project_id='banded-water-276418')  # Edit Hurricane Here.
ivan_q2 = gbq.read_gbq(ivan_2, project_id='banded-water-276418')  # Edit Hurricane Here.
ivan_q3 = gbq.read_gbq(ivan_3, project_id='banded-water-276418')  # Edit Hurricane Here.
ivan_q4 = gbq.read_gbq(ivan_4, project_id='banded-water-276418')  # Edit Hurricane Here.

ivan_df = pd.concat([ivan_q1, ivan_q2, ivan_q3, ivan_q4])

ivan_df.to_csv('datasets/ivan.csv', index=False)
# Out:
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 58.23rows/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 53.12rows/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 61.43rows/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 49.93rows/s]

# %%
FIPS_list_maria = ['72127', '72021', '72013', '72025', '72113']

# %%
for f in FIPS_list:
    for l in range(len(FIPS_list[f]))
        for d in date_list:
            print('SELECT *')
            print(f'FROM "bigquery-public-data.bls_qcew.{d}_q1"')
            print(f'WHERE area_fips={f[l]}')

# %%
cred = service_account.Credentials.from_service_account_file(
    'project 6-a933f6840f90.json', 
    scopes=["https://www.googleapis.com/auth/cloud-platform"]
)

# client = bigquery.Client(
#     credentials = credentials,
#     project = credentials.banded-water-276418
# )

# %%
sql = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q3` AS b
WHERE area_fips = "48201"
"""

# Run a Standard SQL query using the environment's default project
df = pandas.read_gbq(sql, dialect='standard')

# # Run a Standard SQL query with the project set explicitly
# project_id = '100062872363204309014'
# df = pandas.read_gbq(sql, project_id=project_id, dialect='standard')
