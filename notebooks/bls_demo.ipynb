# %%
import requests
import json
import prettytable
import pandas as pd
import bls
from bls_datasets import oes, qcew

# %%
FIPS_list=[]
year_list=range(2014,2019,1)

# %%
df_qcew = qcew.get_data('industry', rtype='dataframe', year='2014', qtr='1', industry='10')
cols=df_qcew.columns

# %%
# desired format for pulling the data
df=pd.DataFrame(columns=cols)
for i in set(year_list):
    for j in (1,2,3,4):
        df_qcew = qcew.get_data('industry', rtype='dataframe', year=str(i), qtr=str(j), industry='10')
        df=pd.concat([df,df_qcew])
df.shape
# Out:
# (384872, 42)

# %%
df_qcew.head(3)
# Out:
#   area_fips  own_code  industry_code  agglvl_code  size_code  year  qtr  \
# 0     01000         0             10           50          0  2015    4
# 1     01000         1             10           51          0  2015    4
# 2     01000         2             10           51          0  2015    4
#
#   disclosure_code  qtrly_estabs  month1_emplvl  ...  oty_month3_emplvl_chg  \
# 0             NaN        121924        1904122  ...                  28146
# 1             NaN          1188          52890  ...                   -266
# 2             NaN          1352          95206  ...                   -439
#
#    oty_month3_emplvl_pct_chg  oty_total_qtrly_wages_chg  \
# 0                        1.5                 1080587499
# 1                       -0.5                   26613198
# 2                       -0.5                   33233168
#
#    oty_total_qtrly_wages_pct_chg  oty_taxable_qtrly_wages_chg  \
# 0                            5.0                     77004135
# ...

# %%
df.groupby(['avg_wkly_wage', 'oty_avg_wkly_wage_pct_chg']).mean()
# Out:
#                                          own_code  industry_code  agglvl_code  \
# avg_wkly_wage oty_avg_wkly_wage_pct_chg
# 0             -100.0                     1.000000           10.0    71.000000
#                0.0                       2.603712           10.0    67.592795
# 198           -16.8                      5.000000           10.0    71.000000
# 262           -11.5                      5.000000           10.0    71.000000
# 269            2.3                       5.000000           10.0    71.000000
# ...                                           ...            ...          ...
# 2574          -0.2                       1.000000           10.0    71.000000
# 2588           0.0                       2.000000           10.0    71.000000
# 2958           6.2                       0.000000           10.0    70.000000
# 2968           0.9                       1.000000           10.0    71.000000
# ...

# %%
df.shape
# Out:
# (384872, 42)

# %%
harris_county_total = df.loc[(df['area_fips']=='48201')|(df['area_fips']=='48245')]

# %%
harris_county_total.head()
# Out:
#       area_fips  own_code  industry_code  agglvl_code  size_code  year  qtr  \
# 13502     48201         0             10           70          0  2017    1
# 13503     48201         1             10           71          0  2017    1
# 13504     48201         2             10           71          0  2017    1
# 13505     48201         3             10           71          0  2017    1
# 13506     48201         5             10           71          0  2017    1
#
#       disclosure_code  qtrly_estabs  month1_emplvl  ...  \
# 13502             NaN        114861        2238117  ...
# 13503             NaN           182          24995  ...
# 13504             NaN            72          52110  ...
# 13505             NaN           303         195408  ...
# 13506             NaN        114304        1965604  ...
#
#        oty_month3_emplvl_chg  oty_month3_emplvl_pct_chg  \
# 13502                  -3755                       -0.2
# ...

# %%
harris_county_total['area_fips'].value_counts()
# Out:
# 48201    5
# 48245    5
# Name: area_fips, dtype: int64

# %%
df.isna().sum()
# Out:
# area_fips                              0
# own_code                               0
# industry_code                          0
# agglvl_code                            0
# size_code                              0
# year                                   0
# qtr                                    0
# disclosure_code                    18325
# qtrly_estabs                           0
# month1_emplvl                          0
# month2_emplvl                          0
# month3_emplvl                          0
# total_qtrly_wages                      0
# taxable_qtrly_wages                    0
# qtrly_contributions                    0
# avg_wkly_wage                          0
# lq_disclosure_code                 18325
# lq_qtrly_estabs                        0
# lq_month1_emplvl                       0
# lq_month2_emplvl                       0
# lq_month3_emplvl                       0
# lq_total_qtrly_wages                   0
# lq_taxable_qtrly_wages                 0
# ...

# %%
#This cell of code takes the bls data for only the fips code in fips list
full_df=pd.DataFrame(columns=cols)
for f in FIPS_list:
    for l in f:
        local_df=df.loc[df['area_fips']==str(l)]
        full_df=pd.concat([full_df,local_df])
#Now save full_df to a csv
full_df.to_csv('path')
