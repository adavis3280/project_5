# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# import requests
# from bs4 import BeautifulSoup
# from pandas.io import gbq
# from google.cloud import bigquery

# name = 'economic-damage-from-natural-disasters'
# df = pd.read_csv('datasets/'+(name)+'.csv')
# df.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Total economic damage from natural disasters (US$)
# 0                                           30000000
# 1                                                  0
# 2                                                  0
# 3                                          480000000
# 4                                                  0

# %%
# with open("datasets/cats-03062020-1123.csv", 'r') as f:
#     lines = f.readlines()

# %%
# lines.value_counts()

# %% [markdown]
# # Google Database BigQuery Code (Start here)>>>

# %%
# !pip install --upgrade google-cloud-bigquery
# !pip install pandas-gbq
# !pip install google-cloud-bigquery

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file("p5_cred.json")
project_id = 'banded-water-276418'

# %%
client = bigquery.Client(credentials= credentials,project='banded-water-276418')

# %%
katrina_data = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q2` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""

katrina_data_q2 = gbq.read_gbq(katrina_data, project_id='banded-water-276418')
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 23.21rows/s]

# %%
katrina_data_q2
# Out:
#    geoid area_fips  qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0  22071     22071                                               13.0
# 1  22089     22089                                                5.0
# 2  22051     22051                                               18.0
# 3  22103     22103                                               33.0
# 4  22075     22075                                               13.0
# 5  22087     22087                                                2.0
#
#    avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 0                                              426.0
# 1                                              373.0
# 2                                              370.0
# 3                                              461.0
# 4                                              361.0
# 5                                                0.0
#
#    month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# ...

# %%
katrina_data = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q3` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""

katrina_data_q3 = gbq.read_gbq(katrina_data, project_id='banded-water-276418')
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 24.60rows/s]

# %%
katrina_data_q3
# Out:
#    geoid area_fips  qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0  22051     22051                                               19.0
# 1  22089     22089                                                5.0
# 2  22075     22075                                               13.0
# 3  22071     22071                                               13.0
# 4  22103     22103                                               32.0
# 5  22087     22087                                                2.0
#
#    avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 0                                              348.0
# 1                                              336.0
# 2                                              287.0
# 3                                              515.0
# 4                                              489.0
# 5                                                0.0
#
#    month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# ...

# %%
katrina_data = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2005_q4` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""

katrina_data_q4 = gbq.read_gbq(katrina_data, project_id='banded-water-276418')
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 27.78rows/s]

# %%
katrina_data_q4
# Out:
#    geoid area_fips  qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0  22075     22075                                               15.0
# 1  22051     22051                                               19.0
# 2  22103     22103                                               31.0
# 3  22071     22071                                               13.0
# 4  22087     22087                                                1.0
# 5  22089     22089                                                5.0
#
#    avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 0                                              379.0
# 1                                              441.0
# 2                                              560.0
# 3                                              708.0
# 4                                                0.0
# 5                                                0.0
#
#    month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# ...

# %%
katrina_df = pd.concat([katrina_data_q2, katrina_data_q3, katrina_data_q4])

# %%
katrina_df.to_csv('katrina.csv', index=False)

# %%
katrina_df
# Out:
#    geoid area_fips  qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0  22071     22071                                               13.0
# 1  22089     22089                                                5.0
# 2  22051     22051                                               18.0
# 3  22103     22103                                               33.0
# 4  22075     22075                                               13.0
# 5  22087     22087                                                2.0
# 0  22051     22051                                               19.0
# 1  22089     22089                                                5.0
# 2  22075     22075                                               13.0
# 3  22071     22071                                               13.0
# 4  22103     22103                                               32.0
# 5  22087     22087                                                2.0
# ...

# %%
FIPS_list_maria = ['72127', '72021', '72013', '72025', '72113']

# %%
for f in FIPS_list:
    for l in range(len(FIPS_list[f]))
        for d in date_list:
            print('SELECT *')
            print(f'FROM "bigquery-public-data.bls_qcew.{d}_q1"')
            print(f'WHERE area_fips={f[l]}')

# %%
# pd.merge(katrina_data_q2, katrina_data_q3)
# Out:
# Empty DataFrame
# ...

# %%
harris_data = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q3` AS b
WHERE  (b.area_fips = '22087' OR 
        b.area_fips = '22071' OR 
        b.area_fips = '22075' OR 
        b.area_fips = '22051' OR 
        b.area_fips = '22103' OR
        b.area_fips = '22089')
"""

harris_data = gbq.read_gbq(harris_data, project_id='banded-water-276418')
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 28.26rows/s]

# %%
fip_list = ['22087', ]

# %%
harris_data
# Out:
#    geoid area_fips  qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0  22075     22075                                               20.0
# 1  22089     22089                                                3.0
# 2  22051     22051                                               20.0
# 3  22071     22071                                               12.0
# 4  22103     22103                                               39.0
# 5  22087     22087                                                2.0
#
#    avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 0                                              535.0
# 1                                              695.0
# 2                                              490.0
# 3                                             1427.0
# 4                                              614.0
# 5                                                0.0
#
#    month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# ...

# %%
cred = service_account.Credentials.from_service_account_file(
    'project 6-a933f6840f90.json', 
    scopes=["https://www.googleapis.com/auth/cloud-platform"]
)

# client = bigquery.Client(
#     credentials = credentials,
#     project = credentials.banded-water-276418
# )

# %%
sql = """
SELECT *
FROM `bigquery-public-data.bls_qcew.2017_q3` AS b
WHERE area_fips = "48201"
"""

# Run a Standard SQL query using the environment's default project
df = pandas.read_gbq(sql, dialect='standard')

# # Run a Standard SQL query with the project set explicitly
# project_id = '100062872363204309014'
# df = pandas.read_gbq(sql, project_id=project_id, dialect='standard')
